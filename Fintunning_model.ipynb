# %% [markdown]
# <a href="https://colab.research.google.com/github/Uzair-DeVops/Quater-2/blob/main/Fintunning_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Install the client library

# %%
# !pip install -q google-generativeai

# %% [markdown]
# ### Import libraries

# %%
import google.generativeai as genai

# %%
from google.colab import userdata
genai.configure(api_key=userdata.get('GOOGLE_API_KEY_5'))

# %% [markdown]
# You can check you existing tuned models with the `genai.list_tuned_model` method.

# %%
for i, m in zip(range(5), genai.list_tuned_models()):
  print(m.name)

# %% [markdown]
# ## Create tuned model

# %% [markdown]
# To create a tuned model, you need to pass your dataset to the model in the `genai.create_tuned_model` method. You can do this be directly defining the input and output values in the call or importing from a file into a dataframe to pass to the method.
#
# For this example, you will tune a model to generate the next number in the sequence. For example, if the input is `1`, the model should output `2`. If the input is `one hundred`, the output should be `one hundred one`.

# %%
base_model = [
    m for m in genai.list_models()
    if "createTunedModel" in m.supported_generation_methods and
    "flash" in m.name][0]
base_model
# Out:
# Model(name='models/gemini-1.5-flash-001-tuning',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.5 Flash 001 Tuning',
#       description=('Version of Gemini 1.5 Flash that supports tuning, our fast and versatile '
#                    'multimodal model for scaling across diverse tasks, released in May of 2024.'),
#       input_token_limit=16384,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens', 'createTunedModel'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=64)

# %%
import random

name = f'generate-num-{random.randint(0,10000)}'
operation = genai.create_tuned_model(
    # You can use a tuned model here too. Set `source_model="tunedModels/..."`
    source_model=base_model.name,
    training_data=[
        {
             'text_input': '1',
             'output': '2',
        },{
             'text_input': '3',
             'output': '4',
        },{
             'text_input': '-3',
             'output': '-2',
        },{
             'text_input': 'twenty two',
             'output': 'twenty three',
        },{
             'text_input': 'two hundred',
             'output': 'two hundred one',
        },{
             'text_input': 'ninety nine',
             'output': 'one hundred',
        },{
             'text_input': '8',
             'output': '9',
        },{
             'text_input': '-98',
             'output': '-97',
        },{
             'text_input': '1,000',
             'output': '1,001',
        },{
             'text_input': '10,100,000',
             'output': '10,100,001',
        },{
             'text_input': 'thirteen',
             'output': 'fourteen',
        },{
             'text_input': 'eighty',
             'output': 'eighty one',
        },{
             'text_input': 'one',
             'output': 'two',
        },{
             'text_input': 'three',
             'output': 'four',
        },{
             'text_input': 'seven',
             'output': 'eight',
        }
    ],
    id = name,
    epoch_count = 100,
    batch_size=4,
    learning_rate=0.001,
)

# %%
random.randint(0,10000)
# Out:
# 9088

# %% [markdown]
# Your tuned model is immediately added to the list of tuned models, but its status is set to "creating" while the model is tuned.

# %%
model = genai.get_tuned_model(f'tunedModels/{name}')

model
# Out:
# TunedModel(name='tunedModels/generate-num-7076',
#            source_model='models/gemini-1.5-flash-001-tuning',
#            base_model='models/gemini-1.5-flash-001-tuning',
#            display_name='',
#            description='',
#            temperature=1.0,
#            top_p=0.95,
#            top_k=64,
#            state=<State.ACTIVE: 2>,
#            create_time=datetime.datetime(2025, 1, 21, 13, 21, 35, 387120, tzinfo=datetime.timezone.utc),
#            update_time=datetime.datetime(2025, 1, 21, 13, 37, 5, 715081, tzinfo=datetime.timezone.utc),
#            tuning_task=TuningTask(start_time=datetime.datetime(2025, 1, 21, 13, 21, 36, 171074, tzinfo=datetime.timezone.utc),
#                                   complete_time=datetime.datetime(2025, 1, 21, 13, 37, 5, 715081, tzinfo=datetime.timezone.utc),
#                                   snapshots=[...],
#                                   hyperparameters=Hyperparameters(epoch_count=100,
#                                                                   batch_size=4,
#                                                                   learning_rate=0.001)),
#            reader_project_numbers=None)

# %%
model.state
# Out:
# <State.ACTIVE: 2>

# %% [markdown]
# ### Check tuning progress

# %% [markdown]
# Use `metadata` to check the state:

# %%
operation.metadata
# Out:
# tuned_model: "tunedModels/generate-num-7076"
# total_steps: 375
# completed_steps: 375
# completed_percent: 100
# snapshots {
#   step: 1
#   mean_loss: 24.1606636
#   compute_time {
#     seconds: 1737465699
#     nanos: 704402633
#   }
# }
# snapshots {
#   step: 2
#   mean_loss: 18.5224419
#   compute_time {
#     seconds: 1737465702
#     nanos: 43406597
#   }
# }
# snapshots {
#   step: 3
#   mean_loss: 17.0722446
#   compute_time {
#     seconds: 1737465704
#     nanos: 399006904
#   }
# }
# snapshots {
#   step: 4
#   epoch: 1
#   mean_loss: 14.0766144
#   compute_time {
#     seconds: 1737465706
#     nanos: 761065794
#   }
# }
# snapshots {
#   step: 5
#   epoch: 1
#   mean_loss: 10.8397322
#   compute_time {
#     seconds: 1737465709
#     nanos: 90413318
#   }
# }
# snapshots {
#   step: 6
#   epoch: 1
#   mean_loss: 7.81541443
#   compute_time {
#     seconds: 1737465711
#     nanos: 415960099
#   }
# }
# snapshots {
#   step: 7
#   epoch: 1
#   mean_loss: 4.71200275
#   compute_time {
#     seconds: 1737465713
#     nanos: 769270931
#   }
# }
# snapshots {
#   step: 8
#   epoch: 2
#   mean_loss: 4.16068172
#   compute_time {
#     seconds: 1737465716
#     nanos: 168877978
#   }
# }
# snapshots {
#   step: 9
#   epoch: 2
#   mean_loss: 2.6309309
#   compute_time {
#     seconds: 1737465718
#     nanos: 423338841
#   }
# }
# snapshots {
#   step: 10
#   epoch: 2
#   mean_loss: 3.90185905
#   compute_time {
#     seconds: 1737465720
#     nanos: 727847025
#   }
# }
# snapshots {
#   step: 11
#   epoch: 2
#   mean_loss: 1.46884489
#   compute_time {
#     seconds: 1737465723
#     nanos: 48781317
#   }
# }
# snapshots {
#   step: 12
#   epoch: 3
#   mean_loss: 1.22781515
#   compute_time {
#     seconds: 1737465725
#     nanos: 561386845
#   }
# }
# snapshots {
#   step: 13
#   epoch: 3
#   mean_loss: 1.0639919
#   compute_time {
#     seconds: 1737465727
#     nanos: 835775265
#   }
# }
# snapshots {
#   step: 14
#   epoch: 3
#   mean_loss: 0.124242447
#   compute_time {
#     seconds: 1737465730
#     nanos: 142904430
#   }
# }
# snapshots {
#   step: 15
#   epoch: 4
#   mean_loss: 0.134667397
#   compute_time {
#     seconds: 1737465732
#     nanos: 466511228
#   }
# }
# snapshots {
#   step: 16
#   epoch: 4
#   mean_loss: 0.0591311716
#   compute_time {
#     seconds: 1737465734
#     nanos: 720720103
#   }
# }
# snapshots {
#   step: 17
#   epoch: 4
#   mean_loss: 0.183706015
#   compute_time {
#     seconds: 1737465737
#     nanos: 15916993
#   }
# }
# snapshots {
#   step: 18
#   epoch: 4
#   mean_loss: 0.495927513
#   compute_time {
#     seconds: 1737465739
#     nanos: 271390640
#   }
# }
# snapshots {
#   step: 19
#   epoch: 5
#   mean_loss: 0.00821549539
#   compute_time {
#     seconds: 1737465742
#     nanos: 283531746
#   }
# }
# snapshots {
#   step: 20
#   epoch: 5
#   mean_loss: 0.00279854983
#   compute_time {
#     seconds: 1737465744
#     nanos: 548846411
#   }
# }
# snapshots {
#   step: 21
#   epoch: 5
#   mean_loss: 0.00430816039
#   compute_time {
#     seconds: 1737465746
#     nanos: 760920021
#   }
# }
# snapshots {
#   step: 22
#   epoch: 5
#   mean_loss: 0.00516793132
#   compute_time {
#     seconds: 1737465749
#     nanos: 18081461
#   }
# }
# snapshots {
#   step: 23
#   epoch: 6
#   mean_loss: 0.00987061486
#   compute_time {
#     seconds: 1737465751
#     nanos: 294893657
#   }
# }
# snapshots {
#   step: 24
#   epoch: 6
#   mean_loss: 2.28517079
#   compute_time {
#     seconds: 1737465753
#     nanos: 606121831
#   }
# }
# snapshots {
#   step: 25
#   epoch: 6
#   mean_loss: 0.00781429745
#   compute_time {
#     seconds: 1737465755
#     nanos: 910386216
#   }
# }
# snapshots {
#   step: 26
#   epoch: 6
#   mean_loss: 0.00499821454
#   compute_time {
#     seconds: 1737465758
#     nanos: 171927612
#   }
# }
# snapshots {
#   step: 27
#   epoch: 7
#   mean_loss: 0.0073407297
#   compute_time {
#     seconds: 1737465761
#     nanos: 524268837
#   }
# }
# snapshots {
#   step: 28
#   epoch: 7
#   mean_loss: 0.000735376263
#   compute_time {
#     seconds: 1737465763
#     nanos: 903622909
#   }
# }
# snapshots {
#   step: 29
#   epoch: 7
#   mean_loss: 1.38489556
#   compute_time {
#     seconds: 1737465766
#     nanos: 173775325
#   }
# }
# snapshots {
#   step: 30
#   epoch: 8
#   mean_loss: 0.0192262419
#   compute_time {
#     seconds: 1737465768
#     nanos: 408513950
#   }
# }
# snapshots {
#   step: 31
#   epoch: 8
#   mean_loss: 0.203076884
#   compute_time {
#     seconds: 1737465770
#     nanos: 669916238
#   }
# }
# snapshots {
#   step: 32
#   epoch: 8
#   mean_loss: 0.0551619083
#   compute_time {
#     seconds: 1737465772
#     nanos: 937899233
#   }
# }
# snapshots {
#   step: 33
#   epoch: 8
#   mean_loss: 0.0020367133
#   compute_time {
#     seconds: 1737465775
#     nanos: 221559257
#   }
# }
# snapshots {
#   step: 34
#   epoch: 9
#   mean_loss: 0.00389012066
#   compute_time {
#     seconds: 1737465777
#     nanos: 477307198
#   }
# }
# snapshots {
#   step: 35
#   epoch: 9
#   mean_loss: 0.00153259828
#   compute_time {
#     seconds: 1737465779
#     nanos: 758379640
#   }
# }
# snapshots {
#   step: 36
#   epoch: 9
#   mean_loss: 0.00773999281
#   compute_time {
#     seconds: 1737465782
#     nanos: 63775291
#   }
# }
# snapshots {
#   step: 37
#   epoch: 9
#   mean_loss: 0.00425888412
#   compute_time {
#     seconds: 1737465784
#     nanos: 335861658
#   }
# }
# snapshots {
#   step: 38
#   epoch: 10
#   mean_loss: 2.82293296
#   compute_time {
#     seconds: 1737465788
#     nanos: 14799460
#   }
# }
# snapshots {
#   step: 39
#   epoch: 10
#   mean_loss: 0.0795419812
#   compute_time {
#     seconds: 1737465791
#     nanos: 429936701
#   }
# }
# snapshots {
#   step: 40
#   epoch: 10
#   mean_loss: 0.00707254559
#   compute_time {
#     seconds: 1737465793
#     nanos: 701333448
#   }
# }
# snapshots {
#   step: 41
#   epoch: 10
#   mean_loss: 1.26366889
#   compute_time {
#     seconds: 1737465795
#     nanos: 941611205
#   }
# }
# snapshots {
#   step: 42
#   epoch: 11
#   mean_loss: 0.0110212266
#   compute_time {
#     seconds: 1737465799
#     nanos: 116476108
#   }
# }
# snapshots {
#   step: 43
#   epoch: 11
#   mean_loss: 0.0195004456
#   compute_time {
#     seconds: 1737465801
#     nanos: 369144275
#   }
# }
# snapshots {
#   step: 44
#   epoch: 11
#   mean_loss: 0.0291791018
#   compute_time {
#     seconds: 1737465804
#     nanos: 428630809
#   }
# }
# snapshots {
#   step: 45
#   epoch: 12
#   mean_loss: 0.392027825
#   compute_time {
#     seconds: 1737465806
#     nanos: 685867164
#   }
# }
# snapshots {
#   step: 46
#   epoch: 12
#   mean_loss: 0.0147948489
#   compute_time {
#     seconds: 1737465809
#     nanos: 593080659
#   }
# }
# snapshots {
#   step: 47
#   epoch: 12
#   mean_loss: 0.0978579521
#   compute_time {
#     seconds: 1737465811
#     nanos: 911368500
#   }
# }
# snapshots {
#   step: 48
#   epoch: 12
#   mean_loss: 0.0447778106
#   compute_time {
#     seconds: 1737465814
#     nanos: 193510801
#   }
# }
# snapshots {
#   step: 49
#   epoch: 13
#   mean_loss: 0.0123530608
#   compute_time {
#     seconds: 1737465816
#     nanos: 460540584
#   }
# }
# snapshots {
#   step: 50
#   epoch: 13
#   mean_loss: 0.00961694773
#   compute_time {
#     seconds: 1737465818
#     nanos: 743827799
#   }
# }
# snapshots {
#   step: 51
#   epoch: 13
#   mean_loss: 0.0835770369
#   compute_time {
#     seconds: 1737465822
#     nanos: 214418652
#   }
# }
# snapshots {
#   step: 52
#   epoch: 13
#   mean_loss: 0.0218971148
#   compute_time {
#     seconds: 1737465824
#     nanos: 505181003
#   }
# }
# snapshots {
#   step: 53
#   epoch: 14
#   mean_loss: 0.00522745261
#   compute_time {
#     seconds: 1737465826
#     nanos: 714496876
#   }
# }
# snapshots {
#   step: 54
#   epoch: 14
#   mean_loss: 0.0462510958
#   compute_time {
#     seconds: 1737465828
#     nanos: 959446104
#   }
# }
# snapshots {
#   step: 55
#   epoch: 14
#   mean_loss: 0.00239564385
#   compute_time {
#     seconds: 1737465831
#     nanos: 197932706
#   }
# }
# snapshots {
#   step: 56
#   epoch: 14
#   mean_loss: 0.00986756943
#   compute_time {
#     seconds: 1737465834
#     nanos: 371582606
#   }
# }
# snapshots {
#   step: 57
#   epoch: 15
#   mean_loss: 0.00701580895
#   compute_time {
#     seconds: 1737465836
#     nanos: 668907483
#   }
# }
# snapshots {
#   step: 58
#   epoch: 15
#   mean_loss: 0.00151718827
#   compute_time {
#     seconds: 1737465838
#     nanos: 974830818
#   }
# }
# snapshots {
#   step: 59
#   epoch: 15
#   mean_loss: 0.00228561
#   compute_time {
#     seconds: 1737465841
#     nanos: 236136444
#   }
# }
# snapshots {
#   step: 60
#   epoch: 16
#   mean_loss: 0.000564082526
#   compute_time {
#     seconds: 1737465843
#     nanos: 500877678
#   }
# }
# snapshots {
#   step: 61
#   epoch: 16
#   mean_loss: 0.00170939718
#   compute_time {
#     seconds: 1737465845
#     nanos: 756425319
#   }
# }
# snapshots {
#   step: 62
#   epoch: 16
#   mean_loss: 0.00136683742
#   compute_time {
#     seconds: 1737465848
#     nanos: 56872231
#   }
# }
# snapshots {
#   step: 63
#   epoch: 16
#   mean_loss: 0.00060857879
#   compute_time {
#     seconds: 1737465850
#     nanos: 326627730
#   }
# }
# snapshots {
#   step: 64
#   epoch: 17
#   mean_loss: 0.000494750682
#   compute_time {
#     seconds: 1737465852
#     nanos: 535406355
#   }
# }
# snapshots {
#   step: 65
#   epoch: 17
#   mean_loss: 0.000240969
#   compute_time {
#     seconds: 1737465854
#     nanos: 767868384
#   }
# }
# snapshots {
#   step: 66
#   epoch: 17
#   mean_loss: 0.000281650719
#   compute_time {
#     seconds: 1737465857
#     nanos: 33815800
#   }
# }
# snapshots {
#   step: 67
#   epoch: 17
#   mean_loss: 0.00103556714
#   compute_time {
#     seconds: 1737465859
#     nanos: 343572608
#   }
# }
# snapshots {
#   step: 68
#   epoch: 18
#   mean_loss: 0.000229850411
#   compute_time {
#     seconds: 1737465862
#     nanos: 881278133
#   }
# }
# snapshots {
#   step: 69
#   epoch: 18
#   mean_loss: 0.000211279897
#   compute_time {
#     seconds: 1737465865
#     nanos: 131149239
#   }
# }
# snapshots {
#   step: 70
#   epoch: 18
#   mean_loss: 0.000401640165
#   compute_time {
#     seconds: 1737465867
#     nanos: 426058951
#   }
# }
# snapshots {
#   step: 71
#   epoch: 18
#   mean_loss: 0.000162534154
#   compute_time {
#     seconds: 1737465869
#     nanos: 708637970
#   }
# }
# snapshots {
#   step: 72
#   epoch: 19
#   mean_loss: 0.000416621915
#   compute_time {
#     seconds: 1737465872
#     nanos: 18818297
#   }
# }
# snapshots {
#   step: 73
#   epoch: 19
#   mean_loss: 0.000217554756
#   compute_time {
#     seconds: 1737465874
#     nanos: 363752302
#   }
# }
# snapshots {
#   step: 74
#   epoch: 19
#   mean_loss: 0.000440145377
#   compute_time {
#     seconds: 1737465876
#     nanos: 581820659
#   }
# }
# snapshots {
#   step: 75
#   epoch: 20
#   mean_loss: 0.00022772362
#   compute_time {
#     seconds: 1737465880
#     nanos: 111115805
#   }
# }
# snapshots {
#   step: 76
#   epoch: 20
#   mean_loss: 0.000170974949
#   compute_time {
#     seconds: 1737465883
#     nanos: 930558759
#   }
# }
# snapshots {
#   step: 77
#   epoch: 20
#   mean_loss: 0.000296676764
#   compute_time {
#     seconds: 1737465886
#     nanos: 248435759
#   }
# }
# snapshots {
#   step: 78
#   epoch: 20
#   mean_loss: 0.000298938947
#   compute_time {
#     seconds: 1737465888
#     nanos: 546990958
#   }
# }
# snapshots {
#   step: 79
#   epoch: 21
#   mean_loss: 0.000162738288
#   compute_time {
#     seconds: 1737465890
#     nanos: 801979004
#   }
# }
# snapshots {
#   step: 80
#   epoch: 21
#   mean_loss: 0.000211046514
#   compute_time {
#     seconds: 1737465893
#     nanos: 36498610
#   }
# }
# snapshots {
#   step: 81
#   epoch: 21
#   mean_loss: 0.000136322313
#   compute_time {
#     seconds: 1737465895
#     nanos: 300770711
#   }
# }
# snapshots {
#   step: 82
#   epoch: 21
#   mean_loss: 0.000266157323
#   compute_time {
#     seconds: 1737465897
#     nanos: 580795006
#   }
# }
# snapshots {
#   step: 83
#   epoch: 22
#   mean_loss: 0.000343451276
#   compute_time {
#     seconds: 1737465901
#     nanos: 292535532
#   }
# }
# snapshots {
#   step: 84
#   epoch: 22
#   mean_loss: 0.000169674895
#   compute_time {
#     seconds: 1737465903
#     nanos: 589341890
#   }
# }
# snapshots {
#   step: 85
#   epoch: 22
#   mean_loss: 5.04510244e-05
#   compute_time {
#     seconds: 1737465905
#     nanos: 818500500
#   }
# }
# snapshots {
#   step: 86
#   epoch: 22
#   mean_loss: 0.000232446473
#   compute_time {
#     seconds: 1737465908
#     nanos: 723354278
#   }
# }
# snapshots {
#   step: 87
#   epoch: 23
#   mean_loss: 0.000259628
#   compute_time {
#     seconds: 1737465910
#     nanos: 996024435
#   }
# }
# snapshots {
#   step: 88
#   epoch: 23
#   mean_loss: 0.000167796854
#   compute_time {
#     seconds: 1737465913
#     nanos: 519905738
#   }
# }
# snapshots {
#   step: 89
#   epoch: 23
#   mean_loss: 0.000160868978
#   compute_time {
#     seconds: 1737465915
#     nanos: 838549281
#   }
# }
# snapshots {
#   step: 90
#   epoch: 24
#   mean_loss: 0.00012436416
#   compute_time {
#     seconds: 1737465918
#     nanos: 94289489
#   }
# }
# snapshots {
#   step: 91
#   epoch: 24
#   mean_loss: 0.000110536086
#   compute_time {
#     seconds: 1737465920
#     nanos: 401802132
#   }
# }
# snapshots {
#   step: 92
#   epoch: 24
#   mean_loss: 0.00012696255
#   compute_time {
#     seconds: 1737465922
#     nanos: 691056018
#   }
# }
# snapshots {
#   step: 93
#   epoch: 24
#   mean_loss: 0.000216296
#   compute_time {
#     seconds: 1737465925
#     nanos: 7391110
#   }
# }
# snapshots {
#   step: 94
#   epoch: 25
#   mean_loss: 0.000165828504
#   compute_time {
#     seconds: 1737465927
#     nanos: 267342731
#   }
# }
# snapshots {
#   step: 95
#   epoch: 25
#   mean_loss: 0.000131818815
#   compute_time {
#     seconds: 1737465929
#     nanos: 579533062
#   }
# }
# snapshots {
#   step: 96
#   epoch: 25
#   mean_loss: 0.000271294848
#   compute_time {
#     seconds: 1737465931
#     nanos: 848717800
#   }
# }
# snapshots {
#   step: 97
#   epoch: 25
#   mean_loss: 5.54225408e-05
#   compute_time {
#     seconds: 1737465934
#     nanos: 143945767
#   }
# }
# snapshots {
#   step: 98
#   epoch: 26
#   mean_loss: 0.000169093721
#   compute_time {
#     seconds: 1737465936
#     nanos: 457010111
#   }
# }
# snapshots {
#   step: 99
#   epoch: 26
#   mean_loss: 3.41845443e-05
#   compute_time {
#     seconds: 1737465938
#     nanos: 764162010
#   }
# }
# snapshots {
#   step: 100
#   epoch: 26
#   mean_loss: 0.000103877566
#   compute_time {
#     seconds: 1737465941
#     nanos: 121178323
#   }
# }
# snapshots {
#   step: 101
#   epoch: 26
#   mean_loss: 0.000265059411
#   compute_time {
#     seconds: 1737465945
#     nanos: 440689906
#   }
# }
# snapshots {
#   step: 102
#   epoch: 27
#   mean_loss: 4.70504165e-05
#   compute_time {
#     seconds: 1737465947
#     nanos: 758329098
#   }
# }
# snapshots {
#   step: 103
#   epoch: 27
#   mean_loss: 0.000153490808
#   compute_time {
#     seconds: 1737465950
#     nanos: 958269092
#   }
# }
# snapshots {
#   step: 104
#   epoch: 27
#   mean_loss: 0.000241096132
#   compute_time {
#     seconds: 1737465953
#     nanos: 269826057
#   }
# }
# snapshots {
#   step: 105
#   epoch: 28
#   mean_loss: 7.36704096e-05
#   compute_time {
#     seconds: 1737465955
#     nanos: 654552762
#   }
# }
# snapshots {
#   step: 106
#   epoch: 28
#   mean_loss: 0.000165845966
#   compute_time {
#     seconds: 1737465957
#     nanos: 946494693
#   }
# }
# snapshots {
#   step: 107
#   epoch: 28
#   mean_loss: 0.000195852946
#   compute_time {
#     seconds: 1737465960
#     nanos: 227943863
#   }
# }
# snapshots {
#   step: 108
#   epoch: 28
#   mean_loss: 7.73634092e-05
#   compute_time {
#     seconds: 1737465962
#     nanos: 574947296
#   }
# }
# snapshots {
#   step: 109
#   epoch: 29
#   mean_loss: 3.46628949e-05
#   compute_time {
#     seconds: 1737465965
#     nanos: 54334428
#   }
# }
# snapshots {
#   step: 110
#   epoch: 29
#   mean_loss: 0.000101760728
#   compute_time {
#     seconds: 1737465967
#     nanos: 369896445
#   }
# }
# snapshots {
#   step: 111
#   epoch: 29
#   mean_loss: 0.000176149537
#   compute_time {
#     seconds: 1737465969
#     nanos: 721267963
#   }
# }
# snapshots {
#   step: 112
#   epoch: 29
#   mean_loss: 0.000132357236
#   compute_time {
#     seconds: 1737465972
#     nanos: 1464855
#   }
# }
# snapshots {
#   step: 113
#   epoch: 30
#   mean_loss: 0.000143244513
#   compute_time {
#     seconds: 1737465974
#     nanos: 301865351
#   }
# }
# snapshots {
#   step: 114
#   epoch: 30
#   mean_loss: 0.000141222728
#   compute_time {
#     seconds: 1737465976
#     nanos: 636072208
#   }
# }
# snapshots {
#   step: 115
#   epoch: 30
#   mean_loss: 9.48633533e-05
#   compute_time {
#     seconds: 1737465978
#     nanos: 991401422
#   }
# }
# snapshots {
#   step: 116
#   epoch: 30
#   mean_loss: 5.30208927e-05
#   compute_time {
#     seconds: 1737465981
#     nanos: 361393560
#   }
# }
# snapshots {
#   step: 117
#   epoch: 31
#   mean_loss: 0.00021772366
#   compute_time {
#     seconds: 1737465983
#     nanos: 660858043
#   }
# }
# snapshots {
#   step: 118
#   epoch: 31
#   mean_loss: 4.19321586e-05
#   compute_time {
#     seconds: 1737465986
#     nanos: 25910271
#   }
# }
# snapshots {
#   step: 119
#   epoch: 31
#   mean_loss: 0.000104569132
#   compute_time {
#     seconds: 1737465988
#     nanos: 315966113
#   }
# }
# snapshots {
#   step: 120
#   epoch: 32
#   mean_loss: 0.000100926962
#   compute_time {
#     seconds: 1737465990
#     nanos: 541543890
#   }
# }
# snapshots {
#   step: 121
#   epoch: 32
#   mean_loss: 7.20536336e-05
#   compute_time {
#     seconds: 1737465992
#     nanos: 835016317
#   }
# }
# snapshots {
#   step: 122
#   epoch: 32
#   mean_loss: 0.000174351968
#   compute_time {
#     seconds: 1737465995
#     nanos: 111022870
#   }
# }
# snapshots {
#   step: 123
#   epoch: 32
#   mean_loss: 5.69117256e-05
#   compute_time {
#     seconds: 1737465997
#     nanos: 334580173
#   }
# }
# snapshots {
#   step: 124
#   epoch: 33
#   mean_loss: 0.000152819324
#   compute_time {
#     seconds: 1737465999
#     nanos: 620839617
#   }
# }
# snapshots {
#   step: 125
#   epoch: 33
#   mean_loss: 7.76705e-05
#   compute_time {
#     seconds: 1737466001
#     nanos: 860673382
#   }
# }
# snapshots {
#   step: 126
#   epoch: 33
#   mean_loss: 7.7428529e-05
#   compute_time {
#     seconds: 1737466005
#     nanos: 496859673
#   }
# }
# snapshots {
#   step: 127
#   epoch: 33
#   mean_loss: 8.50593206e-05
#   compute_time {
#     seconds: 1737466007
#     nanos: 904314170
#   }
# }
# snapshots {
#   step: 128
#   epoch: 34
#   mean_loss: 0.000162244192
#   compute_time {
#     seconds: 1737466010
#     nanos: 176261792
#   }
# }
# snapshots {
#   step: 129
#   epoch: 34
#   mean_loss: 8.1453938e-05
#   compute_time {
#     seconds: 1737466012
#     nanos: 432804758
#   }
# }
# snapshots {
#   step: 130
#   epoch: 34
#   mean_loss: 0.000104648614
#   compute_time {
#     seconds: 1737466014
#     nanos: 704360142
#   }
# }
# snapshots {
#   step: 131
#   epoch: 34
#   mean_loss: 0.00014198781
#   compute_time {
#     seconds: 1737466016
#     nanos: 948483131
#   }
# }
# snapshots {
#   step: 132
#   epoch: 35
#   mean_loss: 0.000131954439
#   compute_time {
#     seconds: 1737466019
#     nanos: 221536666
#   }
# }
# snapshots {
#   step: 133
#   epoch: 35
#   mean_loss: 0.000120432422
#   compute_time {
#     seconds: 1737466022
#     nanos: 9514996
#   }
# }
# snapshots {
#   step: 134
#   epoch: 35
#   mean_loss: 3.22688793e-05
#   compute_time {
#     seconds: 1737466024
#     nanos: 254906588
#   }
# }
# snapshots {
#   step: 135
#   epoch: 36
#   mean_loss: 0.000115647446
#   compute_time {
#     seconds: 1737466026
#     nanos: 507467489
#   }
# }
# snapshots {
#   step: 136
#   epoch: 36
#   mean_loss: 0.000162625918
#   compute_time {
#     seconds: 1737466028
#     nanos: 739817784
#   }
# }
# snapshots {
#   step: 137
#   epoch: 36
#   mean_loss: 6.46932094e-05
#   compute_time {
#     seconds: 1737466031
#     nanos: 74701728
#   }
# }
# snapshots {
#   step: 138
#   epoch: 36
#   mean_loss: 0.000100136618
#   compute_time {
#     seconds: 1737466033
#     nanos: 329664864
#   }
# }
# snapshots {
#   step: 139
#   epoch: 37
#   mean_loss: 0.000130249769
#   compute_time {
#     seconds: 1737466036
#     nanos: 996544540
#   }
# }
# snapshots {
#   step: 140
#   epoch: 37
#   mean_loss: 8.44260212e-05
#   compute_time {
#     seconds: 1737466039
#     nanos: 305197267
#   }
# }
# snapshots {
#   step: 141
#   epoch: 37
#   mean_loss: 0.0001111452
#   compute_time {
#     seconds: 1737466041
#     nanos: 533485338
#   }
# }
# snapshots {
#   step: 142
#   epoch: 37
#   mean_loss: 4.02085716e-05
#   compute_time {
#     seconds: 1737466043
#     nanos: 832964341
#   }
# }
# snapshots {
#   step: 143
#   epoch: 38
#   mean_loss: 5.53825885e-05
#   compute_time {
#     seconds: 1737466046
#     nanos: 99392845
#   }
# }
# snapshots {
#   step: 144
#   epoch: 38
#   mean_loss: 0.000133315101
#   compute_time {
#     seconds: 1737466048
#     nanos: 421063837
#   }
# }
# snapshots {
#   step: 145
#   epoch: 38
#   mean_loss: 8.14136729e-05
#   compute_time {
#     seconds: 1737466050
#     nanos: 637646052
#   }
# }
# snapshots {
#   step: 146
#   epoch: 38
#   mean_loss: 8.68883944e-05
#   compute_time {
#     seconds: 1737466052
#     nanos: 909417018
#   }
# }
# snapshots {
#   step: 147
#   epoch: 39
#   mean_loss: 6.66351043e-05
#   compute_time {
#     seconds: 1737466055
#     nanos: 420022553
#   }
# }
# snapshots {
#   step: 148
#   epoch: 39
#   mean_loss: 9.53171402e-05
#   compute_time {
#     seconds: 1737466057
#     nanos: 713535399
#   }
# }
# snapshots {
#   step: 149
#   epoch: 39
#   mean_loss: 6.56672055e-05
#   compute_time {
#     seconds: 1737466059
#     nanos: 981758892
#   }
# }
# snapshots {
#   step: 150
#   epoch: 40
#   mean_loss: 0.000129993321
#   compute_time {
#     seconds: 1737466062
#     nanos: 263560491
#   }
# }
# snapshots {
#   step: 151
#   epoch: 40
#   mean_loss: 0.000111728674
#   compute_time {
#     seconds: 1737466066
#     nanos: 541260845
#   }
# }
# snapshots {
#   step: 152
#   epoch: 40
#   mean_loss: 7.16224313e-05
#   compute_time {
#     seconds: 1737466068
#     nanos: 778496036
#   }
# }
# snapshots {
#   step: 153
#   epoch: 40
#   mean_loss: 7.78518151e-05
#   compute_time {
#     seconds: 1737466071
#     nanos: 131782631
#   }
# }
# snapshots {
#   step: 154
#   epoch: 41
#   mean_loss: 8.97066639e-05
#   compute_time {
#     seconds: 1737466073
#     nanos: 405487580
#   }
# }
# snapshots {
#   step: 155
#   epoch: 41
#   mean_loss: 6.10971765e-05
#   compute_time {
#     seconds: 1737466076
#     nanos: 204422709
#   }
# }
# snapshots {
#   step: 156
#   epoch: 41
#   mean_loss: 0.000142923789
#   compute_time {
#     seconds: 1737466078
#     nanos: 505778573
#   }
# }
# snapshots {
#   step: 157
#   epoch: 41
#   mean_loss: 8.22017901e-05
#   compute_time {
#     seconds: 1737466082
#     nanos: 65788107
#   }
# }
# snapshots {
#   step: 158
#   epoch: 42
#   mean_loss: 9.46397049e-05
#   compute_time {
#     seconds: 1737466084
#     nanos: 358967554
#   }
# }
# snapshots {
#   step: 159
#   epoch: 42
#   mean_loss: 5.86465467e-05
#   compute_time {
#     seconds: 1737466086
#     nanos: 654031844
#   }
# }
# snapshots {
#   step: 160
#   epoch: 42
#   mean_loss: 5.20966605e-05
#   compute_time {
#     seconds: 1737466088
#     nanos: 915950437
#   }
# }
# snapshots {
#   step: 161
#   epoch: 42
#   mean_loss: 7.2847819e-05
#   compute_time {
#     seconds: 1737466091
#     nanos: 155944228
#   }
# }
# snapshots {
#   step: 162
#   epoch: 43
#   mean_loss: 7.59351533e-05
#   compute_time {
#     seconds: 1737466093
#     nanos: 473435743
#   }
# }
# snapshots {
#   step: 163
#   epoch: 43
#   mean_loss: 6.38957135e-05
#   compute_time {
#     seconds: 1737466095
#     nanos: 731394139
#   }
# }
# snapshots {
#   step: 164
#   epoch: 43
#   mean_loss: 0.000106838306
#   compute_time {
#     seconds: 1737466098
#     nanos: 21348984
#   }
# }
# snapshots {
#   step: 165
#   epoch: 44
#   mean_loss: 8.76146369e-05
#   compute_time {
#     seconds: 1737466100
#     nanos: 300645751
#   }
# }
# snapshots {
#   step: 166
#   epoch: 44
#   mean_loss: 7.19520613e-05
#   compute_time {
#     seconds: 1737466102
#     nanos: 579694575
#   }
# }
# snapshots {
#   step: 167
#   epoch: 44
#   mean_loss: 4.99341404e-05
#   compute_time {
#     seconds: 1737466105
#     nanos: 457888280
#   }
# }
# snapshots {
#   step: 168
#   epoch: 44
#   mean_loss: 9.66154039e-05
#   compute_time {
#     seconds: 1737466107
#     nanos: 786303794
#   }
# }
# snapshots {
#   step: 169
#   epoch: 45
#   mean_loss: 6.80636731e-05
#   compute_time {
#     seconds: 1737466110
#     nanos: 61522145
#   }
# }
# snapshots {
#   step: 170
#   epoch: 45
#   mean_loss: 5.28421806e-05
#   compute_time {
#     seconds: 1737466112
#     nanos: 367514730
#   }
# }
# snapshots {
#   step: 171
#   epoch: 45
#   mean_loss: 6.76054042e-05
#   compute_time {
#     seconds: 1737466115
#     nanos: 136517246
#   }
# }
# snapshots {
#   step: 172
#   epoch: 45
#   mean_loss: 0.000119517485
#   compute_time {
#     seconds: 1737466118
#     nanos: 15980571
#   }
# }
# snapshots {
#   step: 173
#   epoch: 46
#   mean_loss: 5.82058e-05
#   compute_time {
#     seconds: 1737466120
#     nanos: 291417601
#   }
# }
# snapshots {
#   step: 174
#   epoch: 46
#   mean_loss: 0.000129173277
#   compute_time {
#     seconds: 1737466122
#     nanos: 624791861
#   }
# }
# snapshots {
#   step: 175
#   epoch: 46
#   mean_loss: 6.26634574e-05
#   compute_time {
#     seconds: 1737466125
#     nanos: 847976431
#   }
# }
# snapshots {
#   step: 176
#   epoch: 46
#   mean_loss: 5.35432409e-05
#   compute_time {
#     seconds: 1737466128
#     nanos: 116621899
#   }
# }
# snapshots {
#   step: 177
#   epoch: 47
#   mean_loss: 5.63912145e-05
#   compute_time {
#     seconds: 1737466130
#     nanos: 415792434
#   }
# }
# snapshots {
#   step: 178
#   epoch: 47
#   mean_loss: 5.66393137e-05
#   compute_time {
#     seconds: 1737466132
#     nanos: 653227829
#   }
# }
# snapshots {
#   step: 179
#   epoch: 47
#   mean_loss: 5.33482525e-05
#   compute_time {
#     seconds: 1737466134
#     nanos: 928592371
#   }
# }
# snapshots {
#   step: 180
#   epoch: 48
#   mean_loss: 0.000117008691
#   compute_time {
#     seconds: 1737466137
#     nanos: 174040692
#   }
# }
# snapshots {
#   step: 181
#   epoch: 48
#   mean_loss: 6.90858578e-05
#   compute_time {
#     seconds: 1737466139
#     nanos: 431574304
#   }
# }
# snapshots {
#   step: 182
#   epoch: 48
#   mean_loss: 0.000114096794
#   compute_time {
#     seconds: 1737466141
#     nanos: 694199085
#   }
# }
# snapshots {
#   step: 183
#   epoch: 48
#   mean_loss: 5.50246332e-05
#   compute_time {
#     seconds: 1737466145
#     nanos: 195913375
#   }
# }
# snapshots {
#   step: 184
#   epoch: 49
#   mean_loss: 4.24736645e-05
#   compute_time {
#     seconds: 1737466147
#     nanos: 459673216
#   }
# }
# snapshots {
#   step: 185
#   epoch: 49
#   mean_loss: 9.98724718e-05
#   compute_time {
#     seconds: 1737466149
#     nanos: 714406111
#   }
# }
# snapshots {
#   step: 186
#   epoch: 49
#   mean_loss: 3.90260539e-05
#   compute_time {
#     seconds: 1737466152
#     nanos: 24786046
#   }
# }
# snapshots {
#   step: 187
#   epoch: 49
#   mean_loss: 7.49395695e-05
#   compute_time {
#     seconds: 1737466154
#     nanos: 326755144
#   }
# }
# snapshots {
#   step: 188
#   epoch: 50
#   mean_loss: 4.62636599e-05
#   compute_time {
#     seconds: 1737466156
#     nanos: 585367690
#   }
# }
# snapshots {
#   step: 189
#   epoch: 50
#   mean_loss: 8.07732431e-05
#   compute_time {
#     seconds: 1737466158
#     nanos: 826264913
#   }
# }
# snapshots {
#   step: 190
#   epoch: 50
#   mean_loss: 5.26518415e-05
#   compute_time {
#     seconds: 1737466161
#     nanos: 168457200
#   }
# }
# snapshots {
#   step: 191
#   epoch: 50
#   mean_loss: 6.96879215e-05
#   compute_time {
#     seconds: 1737466163
#     nanos: 424743661
#   }
# }
# snapshots {
#   step: 192
#   epoch: 51
#   mean_loss: 8.0792e-05
#   compute_time {
#     seconds: 1737466166
#     nanos: 944160094
#   }
# }
# snapshots {
#   step: 193
#   epoch: 51
#   mean_loss: 0.00010286225
#   compute_time {
#     seconds: 1737466169
#     nanos: 220298054
#   }
# }
# snapshots {
#   step: 194
#   epoch: 51
#   mean_loss: 6.457977e-05
#   compute_time {
#     seconds: 1737466171
#     nanos: 469259965
#   }
# }
# snapshots {
#   step: 195
#   epoch: 52
#   mean_loss: 2.06974801e-05
#   compute_time {
#     seconds: 1737466173
#     nanos: 788728756
#   }
# }
# snapshots {
#   step: 196
#   epoch: 52
#   mean_loss: 9.82240308e-05
#   compute_time {
#     seconds: 1737466176
#     nanos: 24891481
#   }
# }
# snapshots {
#   step: 197
#   epoch: 52
#   mean_loss: 5.53492e-05
#   compute_time {
#     seconds: 1737466178
#     nanos: 250462382
#   }
# }
# snapshots {
#   step: 198
#   epoch: 52
#   mean_loss: 6.57525379e-05
#   compute_time {
#     seconds: 1737466181
#     nanos: 911625758
#   }
# }
# snapshots {
#   step: 199
#   epoch: 53
#   mean_loss: 3.77427677e-05
#   compute_time {
#     seconds: 1737466184
#     nanos: 243050377
#   }
# }
# snapshots {
#   step: 200
#   epoch: 53
#   mean_loss: 4.51364904e-05
#   compute_time {
#     seconds: 1737466187
#     nanos: 322334089
#   }
# }
# snapshots {
#   step: 201
#   epoch: 53
#   mean_loss: 5.13906125e-05
#   compute_time {
#     seconds: 1737466189
#     nanos: 537547250
#   }
# }
# snapshots {
#   step: 202
#   epoch: 53
#   mean_loss: 4.01616562e-05
#   compute_time {
#     seconds: 1737466191
#     nanos: 774584773
#   }
# }
# snapshots {
#   step: 203
#   epoch: 54
#   mean_loss: 9.3961833e-05
#   compute_time {
#     seconds: 1737466194
#     nanos: 8654031
#   }
# }
# snapshots {
#   step: 204
#   epoch: 54
#   mean_loss: 5.72060235e-05
#   compute_time {
#     seconds: 1737466197
#     nanos: 663902167
#   }
# }
# snapshots {
#   step: 205
#   epoch: 54
#   mean_loss: 3.9320621e-05
#   compute_time {
#     seconds: 1737466199
#     nanos: 923594550
#   }
# }
# snapshots {
#   step: 206
#   epoch: 54
#   mean_loss: 0.000120145967
#   compute_time {
#     seconds: 1737466202
#     nanos: 192137876
#   }
# }
# snapshots {
#   step: 207
#   epoch: 55
#   mean_loss: 7.87435565e-05
#   compute_time {
#     seconds: 1737466204
#     nanos: 495945371
#   }
# }
# snapshots {
#   step: 208
#   epoch: 55
#   mean_loss: 6.09771814e-05
#   compute_time {
#     seconds: 1737466206
#     nanos: 710864218
#   }
# }
# snapshots {
#   step: 209
#   epoch: 55
#   mean_loss: 4.24277969e-05
#   compute_time {
#     seconds: 1737466208
#     nanos: 993302325
#   }
# }
# snapshots {
#   step: 210
#   epoch: 56
#   mean_loss: 3.56922937e-05
#   compute_time {
#     seconds: 1737466211
#     nanos: 271353687
#   }
# }
# snapshots {
#   step: 211
#   epoch: 56
#   mean_loss: 3.98264383e-05
#   compute_time {
#     seconds: 1737466213
#     nanos: 670541845
#   }
# }
# snapshots {
#   step: 212
#   epoch: 56
#   mean_loss: 4.29402571e-05
#   compute_time {
#     seconds: 1737466216
#     nanos: 70660651
#   }
# }
# snapshots {
#   step: 213
#   epoch: 56
#   mean_loss: 0.000117688207
#   compute_time {
#     seconds: 1737466218
#     nanos: 401617157
#   }
# }
# snapshots {
#   step: 214
#   epoch: 57
#   mean_loss: 2.8089853e-05
#   compute_time {
#     seconds: 1737466220
#     nanos: 728559958
#   }
# }
# snapshots {
#   step: 215
#   epoch: 57
#   mean_loss: 3.97793483e-05
#   compute_time {
#     seconds: 1737466223
#     nanos: 87738758
#   }
# }
# snapshots {
#   step: 216
#   epoch: 57
#   mean_loss: 0.000111025525
#   compute_time {
#     seconds: 1737466225
#     nanos: 349578613
#   }
# }
# snapshots {
#   step: 217
#   epoch: 57
#   mean_loss: 5.04408963e-05
#   compute_time {
#     seconds: 1737466227
#     nanos: 684370834
#   }
# }
# snapshots {
#   step: 218
#   epoch: 58
#   mean_loss: 3.00011598e-05
#   compute_time {
#     seconds: 1737466229
#     nanos: 963615305
#   }
# }
# snapshots {
#   step: 219
#   epoch: 58
#   mean_loss: 3.25439032e-05
#   compute_time {
#     seconds: 1737466232
#     nanos: 267386352
#   }
# }
# snapshots {
#   step: 220
#   epoch: 58
#   mean_loss: 0.000103358441
#   compute_time {
#     seconds: 1737466234
#     nanos: 531594220
#   }
# }
# snapshots {
#   step: 221
#   epoch: 58
#   mean_loss: 4.30014479e-05
#   compute_time {
#     seconds: 1737466236
#     nanos: 824703579
#   }
# }
# snapshots {
#   step: 222
#   epoch: 59
#   mean_loss: 5.03249466e-05
#   compute_time {
#     seconds: 1737466239
#     nanos: 103467186
#   }
# }
# snapshots {
#   step: 223
#   epoch: 59
#   mean_loss: 4.35693655e-05
#   compute_time {
#     seconds: 1737466241
#     nanos: 376439660
#   }
# }
# snapshots {
#   step: 224
#   epoch: 59
#   mean_loss: 4.07645712e-05
#   compute_time {
#     seconds: 1737466243
#     nanos: 705069902
#   }
# }
# snapshots {
#   step: 225
#   epoch: 60
#   mean_loss: 8.51799268e-05
#   compute_time {
#     seconds: 1737466246
#     nanos: 47793940
#   }
# }
# snapshots {
#   step: 226
#   epoch: 60
#   mean_loss: 4.64615878e-05
#   compute_time {
#     seconds: 1737466250
#     nanos: 715277913
#   }
# }
# snapshots {
#   step: 227
#   epoch: 60
#   mean_loss: 0.000103117462
#   compute_time {
#     seconds: 1737466253
#     nanos: 38468478
#   }
# }
# snapshots {
#   step: 228
#   epoch: 60
#   mean_loss: 4.32576308e-05
#   compute_time {
#     seconds: 1737466255
#     nanos: 354139504
#   }
# }
# snapshots {
#   step: 229
#   epoch: 61
#   mean_loss: 2.80137174e-05
#   compute_time {
#     seconds: 1737466257
#     nanos: 676095870
#   }
# }
# snapshots {
#   step: 230
#   epoch: 61
#   mean_loss: 2.27522105e-05
#   compute_time {
#     seconds: 1737466259
#     nanos: 922855485
#   }
# }
# snapshots {
#   step: 231
#   epoch: 61
#   mean_loss: 5.38181048e-05
#   compute_time {
#     seconds: 1737466262
#     nanos: 252919974
#   }
# }
# snapshots {
#   step: 232
#   epoch: 61
#   mean_loss: 8.88522627e-05
#   compute_time {
#     seconds: 1737466264
#     nanos: 605826698
#   }
# }
# snapshots {
#   step: 233
#   epoch: 62
#   mean_loss: 3.00916145e-05
#   compute_time {
#     seconds: 1737466267
#     nanos: 787643967
#   }
# }
# snapshots {
#   step: 234
#   epoch: 62
#   mean_loss: 0.000104830018
#   compute_time {
#     seconds: 1737466270
#     nanos: 115096771
#   }
# }
# snapshots {
#   step: 235
#   epoch: 62
#   mean_loss: 4.61940654e-05
#   compute_time {
#     seconds: 1737466273
#     nanos: 176350208
#   }
# }
# snapshots {
#   step: 236
#   epoch: 62
#   mean_loss: 2.99930107e-05
#   compute_time {
#     seconds: 1737466276
#     nanos: 494389726
#   }
# }
# snapshots {
#   step: 237
#   epoch: 63
#   mean_loss: 4.43541212e-05
#   compute_time {
#     seconds: 1737466278
#     nanos: 823971512
#   }
# }
# snapshots {
#   step: 238
#   epoch: 63
#   mean_loss: 1.50745191e-05
#   compute_time {
#     seconds: 1737466281
#     nanos: 113795648
#   }
# }
# snapshots {
#   step: 239
#   epoch: 63
#   mean_loss: 3.92973889e-05
#   compute_time {
#     seconds: 1737466283
#     nanos: 430031866
#   }
# }
# snapshots {
#   step: 240
#   epoch: 64
#   mean_loss: 0.000118105905
#   compute_time {
#     seconds: 1737466285
#     nanos: 736651720
#   }
# }
# snapshots {
#   step: 241
#   epoch: 64
#   mean_loss: 2.76311184e-05
#   compute_time {
#     seconds: 1737466289
#     nanos: 170522422
#   }
# }
# snapshots {
#   step: 242
#   epoch: 64
#   mean_loss: 3.61687271e-05
#   compute_time {
#     seconds: 1737466291
#     nanos: 480711286
#   }
# }
# snapshots {
#   step: 243
#   epoch: 64
#   mean_loss: 3.59003898e-05
#   compute_time {
#     seconds: 1737466293
#     nanos: 925515743
#   }
# }
# snapshots {
#   step: 244
#   epoch: 65
#   mean_loss: 8.50006472e-05
#   compute_time {
#     seconds: 1737466296
#     nanos: 231550812
#   }
# }
# snapshots {
#   step: 245
#   epoch: 65
#   mean_loss: 0.000104444916
#   compute_time {
#     seconds: 1737466298
#     nanos: 567332660
#   }
# }
# snapshots {
#   step: 246
#   epoch: 65
#   mean_loss: 3.52406641e-05
#   compute_time {
#     seconds: 1737466300
#     nanos: 915329511
#   }
# }
# snapshots {
#   step: 247
#   epoch: 65
#   mean_loss: 2.86102295e-05
#   compute_time {
#     seconds: 1737466304
#     nanos: 320298613
#   }
# }
# snapshots {
#   step: 248
#   epoch: 66
#   mean_loss: 4.6138608e-05
#   compute_time {
#     seconds: 1737466306
#     nanos: 653860125
#   }
# }
# snapshots {
#   step: 249
#   epoch: 66
#   mean_loss: 8.02363866e-05
#   compute_time {
#     seconds: 1737466310
#     nanos: 517434960
#   }
# }
# snapshots {
#   step: 250
#   epoch: 66
#   mean_loss: 2.22233139e-05
#   compute_time {
#     seconds: 1737466312
#     nanos: 882869278
#   }
# }
# snapshots {
#   step: 251
#   epoch: 66
#   mean_loss: 5.57258027e-05
#   compute_time {
#     seconds: 1737466315
#     nanos: 165933718
#   }
# }
# snapshots {
#   step: 252
#   epoch: 67
#   mean_loss: 2.26845586e-05
#   compute_time {
#     seconds: 1737466317
#     nanos: 457800325
#   }
# }
# snapshots {
#   step: 253
#   epoch: 67
#   mean_loss: 0.000108511653
#   compute_time {
#     seconds: 1737466320
#     nanos: 84521656
#   }
# }
# snapshots {
#   step: 254
#   epoch: 67
#   mean_loss: 1.77922193e-05
#   compute_time {
#     seconds: 1737466322
#     nanos: 528104240
#   }
# }
# snapshots {
#   step: 255
#   epoch: 68
#   mean_loss: 2.86793802e-05
#   compute_time {
#     seconds: 1737466324
#     nanos: 864995040
#   }
# }
# snapshots {
#   step: 256
#   epoch: 68
#   mean_loss: 2.54849438e-05
#   compute_time {
#     seconds: 1737466327
#     nanos: 645511880
#   }
# }
# snapshots {
#   step: 257
#   epoch: 68
#   mean_loss: 4.19728203e-05
#   compute_time {
#     seconds: 1737466330
#     nanos: 314935330
#   }
# }
# snapshots {
#   step: 258
#   epoch: 68
#   mean_loss: 2.04373373e-05
#   compute_time {
#     seconds: 1737466332
#     nanos: 620440438
#   }
# }
# snapshots {
#   step: 259
#   epoch: 69
#   mean_loss: 0.000103170983
#   compute_time {
#     seconds: 1737466336
#     nanos: 396405194
#   }
# }
# snapshots {
#   step: 260
#   epoch: 69
#   mean_loss: 2.67140567e-05
#   compute_time {
#     seconds: 1737466338
#     nanos: 699110248
#   }
# }
# snapshots {
#   step: 261
#   epoch: 69
#   mean_loss: 1.46571547e-05
#   compute_time {
#     seconds: 1737466340
#     nanos: 987661805
#   }
# }
# snapshots {
#   step: 262
#   epoch: 69
#   mean_loss: 7.71071063e-05
#   compute_time {
#     seconds: 1737466343
#     nanos: 321862407
#   }
# }
# snapshots {
#   step: 263
#   epoch: 70
#   mean_loss: 4.7115238e-05
#   compute_time {
#     seconds: 1737466345
#     nanos: 644159417
#   }
# }
# snapshots {
#   step: 264
#   epoch: 70
#   mean_loss: 2.60497509e-05
#   compute_time {
#     seconds: 1737466347
#     nanos: 929220765
#   }
# }
# snapshots {
#   step: 265
#   epoch: 70
#   mean_loss: 9.43555497e-05
#   compute_time {
#     seconds: 1737466350
#     nanos: 294489688
#   }
# }
# snapshots {
#   step: 266
#   epoch: 70
#   mean_loss: 3.40767438e-05
#   compute_time {
#     seconds: 1737466352
#     nanos: 561197338
#   }
# }
# snapshots {
#   step: 267
#   epoch: 71
#   mean_loss: 1.66244572e-05
#   compute_time {
#     seconds: 1737466354
#     nanos: 894354288
#   }
# }
# snapshots {
#   step: 268
#   epoch: 71
#   mean_loss: 3.77696706e-05
#   compute_time {
#     seconds: 1737466357
#     nanos: 257853749
#   }
# }
# snapshots {
#   step: 269
#   epoch: 71
#   mean_loss: 9.67856e-05
#   compute_time {
#     seconds: 1737466359
#     nanos: 633420123
#   }
# }
# snapshots {
#   step: 270
#   epoch: 72
#   mean_loss: 1.9042287e-05
#   compute_time {
#     seconds: 1737466362
#     nanos: 677130267
#   }
# }
# snapshots {
#   step: 271
#   epoch: 72
#   mean_loss: 3.86550091e-05
#   compute_time {
#     seconds: 1737466365
#     nanos: 3545171
#   }
# }
# snapshots {
#   step: 272
#   epoch: 72
#   mean_loss: 9.72345e-05
#   compute_time {
#     seconds: 1737466367
#     nanos: 306791597
#   }
# }
# snapshots {
#   step: 273
#   epoch: 72
#   mean_loss: 1.48839317e-05
#   compute_time {
#     seconds: 1737466372
#     nanos: 842982511
#   }
# }
# snapshots {
#   step: 274
#   epoch: 73
#   mean_loss: 1.98647776e-05
#   compute_time {
#     seconds: 1737466375
#     nanos: 130808616
#   }
# }
# snapshots {
#   step: 275
#   epoch: 73
#   mean_loss: 2.84205489e-05
#   compute_time {
#     seconds: 1737466377
#     nanos: 508176362
#   }
# }
# snapshots {
#   step: 276
#   epoch: 73
#   mean_loss: 4.13542439e-05
#   compute_time {
#     seconds: 1737466379
#     nanos: 844009621
#   }
# }
# snapshots {
#   step: 277
#   epoch: 73
#   mean_loss: 3.18686944e-05
#   compute_time {
#     seconds: 1737466382
#     nanos: 158328674
#   }
# }
# snapshots {
#   step: 278
#   epoch: 74
#   mean_loss: 6.81428937e-05
#   compute_time {
#     seconds: 1737466384
#     nanos: 444121829
#   }
# }
# snapshots {
#   step: 279
#   epoch: 74
#   mean_loss: 5.03274e-05
#   compute_time {
#     seconds: 1737466386
#     nanos: 755442887
#   }
# }
# snapshots {
#   step: 280
#   epoch: 74
#   mean_loss: 2.89596974e-05
#   compute_time {
#     seconds: 1737466389
#     nanos: 32517905
#   }
# }
# snapshots {
#   step: 281
#   epoch: 74
#   mean_loss: 7.83370342e-05
#   compute_time {
#     seconds: 1737466391
#     nanos: 385062891
#   }
# }
# snapshots {
#   step: 282
#   epoch: 75
#   mean_loss: 9.96817835e-06
#   compute_time {
#     seconds: 1737466395
#     nanos: 252252089
#   }
# }
# snapshots {
#   step: 283
#   epoch: 75
#   mean_loss: 7.72126805e-05
#   compute_time {
#     seconds: 1737466397
#     nanos: 541933307
#   }
# }
# snapshots {
#   step: 284
#   epoch: 75
#   mean_loss: 4.1250838e-05
#   compute_time {
#     seconds: 1737466399
#     nanos: 873479361
#   }
# }
# snapshots {
#   step: 285
#   epoch: 76
#   mean_loss: 2.48224896e-05
#   compute_time {
#     seconds: 1737466402
#     nanos: 187566118
#   }
# }
# snapshots {
#   step: 286
#   epoch: 76
#   mean_loss: 1.27761596e-05
#   compute_time {
#     seconds: 1737466404
#     nanos: 491404369
#   }
# }
# snapshots {
#   step: 287
#   epoch: 76
#   mean_loss: 7.91081111e-05
#   compute_time {
#     seconds: 1737466406
#     nanos: 830762938
#   }
# }
# snapshots {
#   step: 288
#   epoch: 76
#   mean_loss: 3.09632596e-05
#   compute_time {
#     seconds: 1737466409
#     nanos: 115244418
#   }
# }
# snapshots {
#   step: 289
#   epoch: 77
#   mean_loss: 3.70001544e-05
#   compute_time {
#     seconds: 1737466411
#     nanos: 483482910
#   }
# }
# snapshots {
#   step: 290
#   epoch: 77
#   mean_loss: 6.61888625e-05
#   compute_time {
#     seconds: 1737466413
#     nanos: 802541709
#   }
# }
# snapshots {
#   step: 291
#   epoch: 77
#   mean_loss: 3.01672735e-05
#   compute_time {
#     seconds: 1737466416
#     nanos: 123438939
#   }
# }
# snapshots {
#   step: 292
#   epoch: 77
#   mean_loss: 3.42784915e-05
#   compute_time {
#     seconds: 1737466419
#     nanos: 515259586
#   }
# }
# snapshots {
#   step: 293
#   epoch: 78
#   mean_loss: 3.38628888e-05
#   compute_time {
#     seconds: 1737466421
#     nanos: 839763907
#   }
# }
# snapshots {
#   step: 294
#   epoch: 78
#   mean_loss: 6.1355182e-05
#   compute_time {
#     seconds: 1737466424
#     nanos: 137271710
#   }
# }
# snapshots {
#   step: 295
#   epoch: 78
#   mean_loss: 1.8648363e-05
#   compute_time {
#     seconds: 1737466426
#     nanos: 425014056
#   }
# }
# snapshots {
#   step: 296
#   epoch: 78
#   mean_loss: 3.45035223e-05
#   compute_time {
#     seconds: 1737466428
#     nanos: 740119693
#   }
# }
# snapshots {
#   step: 297
#   epoch: 79
#   mean_loss: 2.7023847e-05
#   compute_time {
#     seconds: 1737466434
#     nanos: 9971281
#   }
# }
# snapshots {
#   step: 298
#   epoch: 79
#   mean_loss: 7.70762417e-05
#   compute_time {
#     seconds: 1737466436
#     nanos: 338428702
#   }
# }
# snapshots {
#   step: 299
#   epoch: 79
#   mean_loss: 4.0410494e-05
#   compute_time {
#     seconds: 1737466438
#     nanos: 587236213
#   }
# }
# snapshots {
#   step: 300
#   epoch: 80
#   mean_loss: 2.37934291e-05
#   compute_time {
#     seconds: 1737466440
#     nanos: 835005591
#   }
# }
# snapshots {
#   step: 301
#   epoch: 80
#   mean_loss: 1.6521697e-05
#   compute_time {
#     seconds: 1737466443
#     nanos: 103080495
#   }
# }
# snapshots {
#   step: 302
#   epoch: 80
#   mean_loss: 4.14379574e-05
#   compute_time {
#     seconds: 1737466445
#     nanos: 342220569
#   }
# }
# snapshots {
#   step: 303
#   epoch: 80
#   mean_loss: 1.66243371e-05
#   compute_time {
#     seconds: 1737466447
#     nanos: 628813801
#   }
# }
# snapshots {
#   step: 304
#   epoch: 81
#   mean_loss: 0.000107977372
#   compute_time {
#     seconds: 1737466449
#     nanos: 909677871
#   }
# }
# snapshots {
#   step: 305
#   epoch: 81
#   mean_loss: 2.31945778e-05
#   compute_time {
#     seconds: 1737466452
#     nanos: 155944980
#   }
# }
# snapshots {
#   step: 306
#   epoch: 81
#   mean_loss: 2.88791816e-05
#   compute_time {
#     seconds: 1737466454
#     nanos: 409874468
#   }
# }
# snapshots {
#   step: 307
#   epoch: 81
#   mean_loss: 3.04565656e-05
#   compute_time {
#     seconds: 1737466456
#     nanos: 963672548
#   }
# }
# snapshots {
#   step: 308
#   epoch: 82
#   mean_loss: 3.22174747e-05
#   compute_time {
#     seconds: 1737466459
#     nanos: 292584010
#   }
# }
# snapshots {
#   step: 309
#   epoch: 82
#   mean_loss: 2.55057912e-05
#   compute_time {
#     seconds: 1737466461
#     nanos: 570534936
#   }
# }
# snapshots {
#   step: 310
#   epoch: 82
#   mean_loss: 1.66580903e-05
#   compute_time {
#     seconds: 1737466463
#     nanos: 819337258
#   }
# }
# snapshots {
#   step: 311
#   epoch: 82
#   mean_loss: 3.13719393e-05
#   compute_time {
#     seconds: 1737466466
#     nanos: 114967087
#   }
# }
# snapshots {
#   step: 312
#   epoch: 83
#   mean_loss: 5.46606025e-05
#   compute_time {
#     seconds: 1737466468
#     nanos: 358834183
#   }
# }
# snapshots {
#   step: 313
#   epoch: 83
#   mean_loss: 7.0152455e-05
#   compute_time {
#     seconds: 1737466471
#     nanos: 131801210
#   }
# }
# snapshots {
#   step: 314
#   epoch: 83
#   mean_loss: 2.2212711e-05
#   compute_time {
#     seconds: 1737466474
#     nanos: 655535327
#   }
# }
# snapshots {
#   step: 315
#   epoch: 84
#   mean_loss: 3.70395464e-05
#   compute_time {
#     seconds: 1737466476
#     nanos: 940971634
#   }
# }
# snapshots {
#   step: 316
#   epoch: 84
#   mean_loss: 6.20535429e-05
#   compute_time {
#     seconds: 1737466479
#     nanos: 207538879
#   }
# }
# snapshots {
#   step: 317
#   epoch: 84
#   mean_loss: 2.6909087e-05
#   compute_time {
#     seconds: 1737466482
#     nanos: 398802011
#   }
# }
# snapshots {
#   step: 318
#   epoch: 84
#   mean_loss: 3.37176025e-05
#   compute_time {
#     seconds: 1737466484
#     nanos: 652879085
#   }
# }
# snapshots {
#   step: 319
#   epoch: 85
#   mean_loss: 2.25263648e-05
#   compute_time {
#     seconds: 1737466487
#     nanos: 79707140
#   }
# }
# snapshots {
#   step: 320
#   epoch: 85
#   mean_loss: 1.78940718e-05
#   compute_time {
#     seconds: 1737466489
#     nanos: 349472271
#   }
# }
# snapshots {
#   step: 321
#   epoch: 85
#   mean_loss: 3.96537689e-05
#   compute_time {
#     seconds: 1737466493
#     nanos: 115065717
#   }
# }
# snapshots {
#   step: 322
#   epoch: 85
#   mean_loss: 6.75282208e-05
#   compute_time {
#     seconds: 1737466495
#     nanos: 383071784
#   }
# }
# snapshots {
#   step: 323
#   epoch: 86
#   mean_loss: 5.2513431e-05
#   compute_time {
#     seconds: 1737466497
#     nanos: 697177357
#   }
# }
# snapshots {
#   step: 324
#   epoch: 86
#   mean_loss: 2.06835175e-05
#   compute_time {
#     seconds: 1737466499
#     nanos: 942881119
#   }
# }
# snapshots {
#   step: 325
#   epoch: 86
#   mean_loss: 3.07856826e-05
#   compute_time {
#     seconds: 1737466502
#     nanos: 218371118
#   }
# }
# snapshots {
#   step: 326
#   epoch: 86
#   mean_loss: 2.84793841e-05
#   compute_time {
#     seconds: 1737466504
#     nanos: 464869538
#   }
# }
# snapshots {
#   step: 327
#   epoch: 87
#   mean_loss: 1.34897418e-05
#   compute_time {
#     seconds: 1737466507
#     nanos: 914061663
#   }
# }
# snapshots {
#   step: 328
#   epoch: 87
#   mean_loss: 4.20883298e-05
#   compute_time {
#     seconds: 1737466510
#     nanos: 217019243
#   }
# }
# snapshots {
#   step: 329
#   epoch: 87
#   mean_loss: 1.09559624e-05
#   compute_time {
#     seconds: 1737466512
#     nanos: 502553537
#   }
# }
# snapshots {
#   step: 330
#   epoch: 88
#   mean_loss: 6.04039597e-05
#   compute_time {
#     seconds: 1737466514
#     nanos: 790285670
#   }
# }
# snapshots {
#   step: 331
#   epoch: 88
#   mean_loss: 2.19761514e-05
#   compute_time {
#     seconds: 1737466517
#     nanos: 21972453
#   }
# }
# snapshots {
#   step: 332
#   epoch: 88
#   mean_loss: 1.78884638e-05
#   compute_time {
#     seconds: 1737466519
#     nanos: 231311852
#   }
# }
# snapshots {
#   step: 333
#   epoch: 88
#   mean_loss: 3.00647498e-05
#   compute_time {
#     seconds: 1737466521
#     nanos: 509672342
#   }
# }
# snapshots {
#   step: 334
#   epoch: 89
#   mean_loss: 7.24724814e-05
#   compute_time {
#     seconds: 1737466523
#     nanos: 820804388
#   }
# }
# snapshots {
#   step: 335
#   epoch: 89
#   mean_loss: 5.02460607e-05
#   compute_time {
#     seconds: 1737466526
#     nanos: 86489163
#   }
# }
# snapshots {
#   step: 336
#   epoch: 89
#   mean_loss: 3.86012325e-05
#   compute_time {
#     seconds: 1737466528
#     nanos: 352405630
#   }
# }
# snapshots {
#   step: 337
#   epoch: 89
#   mean_loss: 1.39357289e-05
#   compute_time {
#     seconds: 1737466530
#     nanos: 657181205
#   }
# }
# snapshots {
#   step: 338
#   epoch: 90
#   mean_loss: 3.36032754e-05
#   compute_time {
#     seconds: 1737466532
#     nanos: 960946309
#   }
# }
# snapshots {
#   step: 339
#   epoch: 90
#   mean_loss: 6.11183e-05
#   compute_time {
#     seconds: 1737466535
#     nanos: 207588020
#   }
# }
# snapshots {
#   step: 340
#   epoch: 90
#   mean_loss: 1.18162716e-05
#   compute_time {
#     seconds: 1737466537
#     nanos: 534306043
#   }
# }
# snapshots {
#   step: 341
#   epoch: 90
#   mean_loss: 2.38383982e-05
#   compute_time {
#     seconds: 1737466539
#     nanos: 852177318
#   }
# }
# snapshots {
#   step: 342
#   epoch: 91
#   mean_loss: 2.93896373e-05
#   compute_time {
#     seconds: 1737466542
#     nanos: 121605552
#   }
# }
# snapshots {
#   step: 343
#   epoch: 91
#   mean_loss: 6.28203852e-05
#   compute_time {
#     seconds: 1737466544
#     nanos: 386064021
#   }
# }
# snapshots {
#   step: 344
#   epoch: 91
#   mean_loss: 8.49005301e-06
#   compute_time {
#     seconds: 1737466546
#     nanos: 658670336
#   }
# }
# snapshots {
#   step: 345
#   epoch: 92
#   mean_loss: 2.44301773e-05
#   compute_time {
#     seconds: 1737466549
#     nanos: 280262994
#   }
# }
# snapshots {
#   step: 346
#   epoch: 92
#   mean_loss: 2.21836453e-05
#   compute_time {
#     seconds: 1737466551
#     nanos: 511086276
#   }
# }
# snapshots {
#   step: 347
#   epoch: 92
#   mean_loss: 2.42178685e-05
#   compute_time {
#     seconds: 1737466555
#     nanos: 415658968
#   }
# }
# snapshots {
#   step: 348
#   epoch: 92
#   mean_loss: 8.61380249e-06
#   compute_time {
#     seconds: 1737466557
#     nanos: 709931865
#   }
# }
# snapshots {
#   step: 349
#   epoch: 93
#   mean_loss: 7.59250252e-05
#   compute_time {
#     seconds: 1737466560
#     nanos: 14424752
#   }
# }
# snapshots {
#   step: 350
#   epoch: 93
#   mean_loss: 1.92151801e-05
#   compute_time {
#     seconds: 1737466562
#     nanos: 279240959
#   }
# }
# snapshots {
#   step: 351
#   epoch: 93
#   mean_loss: 6.25442917e-05
#   compute_time {
#     seconds: 1737466564
#     nanos: 499336441
#   }
# }
# snapshots {
#   step: 352
#   epoch: 93
#   mean_loss: 1.64533067e-05
#   compute_time {
#     seconds: 1737466566
#     nanos: 818413236
#   }
# }
# snapshots {
#   step: 353
#   epoch: 94
#   mean_loss: 2.76016071e-05
#   compute_time {
#     seconds: 1737466569
#     nanos: 136792237
#   }
# }
# snapshots {
#   step: 354
#   epoch: 94
#   mean_loss: 3.90342975e-05
#   compute_time {
#     seconds: 1737466572
#     nanos: 318971766
#   }
# }
# snapshots {
#   step: 355
#   epoch: 94
#   mean_loss: 7.23771518e-06
#   compute_time {
#     seconds: 1737466574
#     nanos: 581203251
#   }
# }
# snapshots {
#   step: 356
#   epoch: 94
#   mean_loss: 4.88890801e-05
#   compute_time {
#     seconds: 1737466576
#     nanos: 821227847
#   }
# }
# snapshots {
#   step: 357
#   epoch: 95
#   mean_loss: 1.99126152e-05
#   compute_time {
#     seconds: 1737466579
#     nanos: 74858411
#   }
# }
# snapshots {
#   step: 358
#   epoch: 95
#   mean_loss: 2.49806326e-05
#   compute_time {
#     seconds: 1737466581
#     nanos: 878482040
#   }
# }
# snapshots {
#   step: 359
#   epoch: 95
#   mean_loss: 2.43361574e-05
#   compute_time {
#     seconds: 1737466584
#     nanos: 180868299
#   }
# }
# snapshots {
#   step: 360
#   epoch: 96
#   mean_loss: 4.55821028e-05
#   compute_time {
#     seconds: 1737466586
#     nanos: 510519463
#   }
# }
# snapshots {
#   step: 361
#   epoch: 96
#   mean_loss: 1.40765915e-05
#   compute_time {
#     seconds: 1737466588
#     nanos: 848225465
#   }
# }
# snapshots {
#   step: 362
#   epoch: 96
#   mean_loss: 3.291131e-05
#   compute_time {
#     seconds: 1737466591
#     nanos: 122039002
#   }
# }
# snapshots {
#   step: 363
#   epoch: 96
#   mean_loss: 4.99396301e-05
#   compute_time {
#     seconds: 1737466593
#     nanos: 405138403
#   }
# }
# snapshots {
#   step: 364
#   epoch: 97
#   mean_loss: 2.79226806e-05
#   compute_time {
#     seconds: 1737466596
#     nanos: 384378476
#   }
# }
# snapshots {
#   step: 365
#   epoch: 97
#   mean_loss: 2.69132433e-05
#   compute_time {
#     seconds: 1737466598
#     nanos: 674925580
#   }
# }
# snapshots {
#   step: 366
#   epoch: 97
#   mean_loss: 1.39724e-05
#   compute_time {
#     seconds: 1737466600
#     nanos: 970835845
#   }
# }
# snapshots {
#   step: 367
#   epoch: 97
#   mean_loss: 2.01388029e-05
#   compute_time {
#     seconds: 1737466603
#     nanos: 314979076
#   }
# }
# snapshots {
#   step: 368
#   epoch: 98
#   mean_loss: 4.57678616e-05
#   compute_time {
#     seconds: 1737466605
#     nanos: 604008151
#   }
# }
# snapshots {
#   step: 369
#   epoch: 98
#   mean_loss: 5.45819021e-05
#   compute_time {
#     seconds: 1737466607
#     nanos: 964725585
#   }
# }
# snapshots {
#   step: 370
#   epoch: 98
#   mean_loss: 2.21384507e-05
#   compute_time {
#     seconds: 1737466610
#     nanos: 258333434
#   }
# }
# snapshots {
#   step: 371
#   epoch: 98
#   mean_loss: 2.13466119e-05
#   compute_time {
#     seconds: 1737466612
#     nanos: 590686019
#   }
# }
# snapshots {
#   step: 372
#   epoch: 99
#   mean_loss: 2.99137773e-05
#   compute_time {
#     seconds: 1737466616
#     nanos: 350421021
#   }
# }
# snapshots {
#   step: 373
#   epoch: 99
#   mean_loss: 2.40609515e-05
#   compute_time {
#     seconds: 1737466618
#     nanos: 746764628
#   }
# }
# snapshots {
#   step: 374
#   epoch: 99
#   mean_loss: 1.89669663e-05
#   compute_time {
#     seconds: 1737466621
#     nanos: 58901456
#   }
# }
# snapshots {
#   step: 375
#   epoch: 100
#   mean_loss: 4.75957058e-05
#   compute_time {
#     seconds: 1737466623
#     nanos: 407391306
#   }
# }

# %% [markdown]
# Wait for the training to finish using `operation.result()`, or `operation.wait_bar()`

# %%
import time

for status in operation.wait_bar():
  time.sleep(30)
# Out:
#   0%|          | 0/375 [00:00<?, ?it/s]

# %% [markdown]
# You can cancel your tuning job any time using the `cancel()` method. Uncomment the line below and run the code cell to cancel your job before it finishes.

# %%
# operation.cancel()

# %% [markdown]
# Once the tuning is complete, you can view the loss curve from the tuning results. The [loss curve](https://ai.google.dev/gemini-api/docs/model-tuning#recommended_configurations) shows how much the model's predictions deviate from the ideal outputs.

# %%
import pandas as pd
import seaborn as sns

model = operation.result()

snapshots = pd.DataFrame(model.tuning_task.snapshots)

sns.lineplot(data=snapshots, x = 'epoch', y='mean_loss')
# Out:
# <Axes: xlabel='epoch', ylabel='mean_loss'>

# %% [markdown]
# ## Evaluate your model
#
# You can use the `genai.generate_content` method and specify the name of your model to test your model performance.

# %%
model = genai.GenerativeModel(model_name=f'tunedModels/{name}')

# %%
result = model.generate_content('55')
result.text
# Out:
# '55'

# %%
result = model.generate_content('123455')
result.text
# Out:
# '123456'

# %%
result = model.generate_content('four')
result.text
# Out:
# 'five'

# %%
result = model.generate_content('quatre') # French 4
result.text                               # French 5 is "cinq"
# Out:
# 'cinq'

# %%
result = model.generate_content('III')    # Roman numeral 3
result.text                               # Roman numeral 4 is IV
# Out:
# 'IV'

# %%
result = model.generate_content('七')  # Japanese 7
result.text                            # Japanese 8 is 八!
# Out:
# '八'

# %% [markdown]
# It really seems to have picked up the task despite the limited examples, but "next" is a simple concept, see the [tuning guide](https://ai.google.dev/gemini-api/docs/model-tuning) for more guidance on improving performance.

# %% [markdown]
# ## Update the description
#
# You can update the description of your tuned model any time using the `genai.update_tuned_model` method.

# %%
genai.update_tuned_model(f'tunedModels/{name}', {"description":"This is my model."});

# %%
model = genai.get_tuned_model(f'tunedModels/{name}')

model.description
# Out:
# 'This is my model.'

# %% [markdown]
# ## Delete the model
#
# You can clean up your tuned model list by deleting models you no longer need. Use the `genai.delete_tuned_model` method to delete a model. If you canceled any tuning jobs, you may want to delete those as their performance may be unpredictable.

# %%
genai.delete_tuned_model(f'tunedModels/{name}')

# %% [markdown]
# The model no longer exists:

# %%
try:
  m = genai.get_tuned_model(f'tunedModels/{name}')
  print(m)
except Exception as e:
  print(f"{type(e)}: {e}")
# Out:
# <class 'google.api_core.exceptions.NotFound'>: 404 GET https://generativelanguage.googleapis.com/v1beta/tunedModels/generate-num-8122?%24alt=json%3Benum-encoding%3Dint: Tuned model tunedModels/generate-num-8122 does not exist.
# WARNING:tornado.access:404 GET /v1beta/tunedModels/generate-num-8122?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 838.85ms
